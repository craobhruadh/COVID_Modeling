# %% [markdown]
# # Date exploration
#
# Data is taken from: http://publichealth.lacounty.gov/media/coronavirus/data/

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# !ls ../data
# Out:
# ls: ../data: No such file or directory

# %%
df = pd.read_csv(
    './data/LA_County_Covid19_cases_deaths_date_table.csv', 
    parse_dates=['date_use'], 
    index_col = 0
)
df.head()
# Out:
#     date_use  total_cases  new_case  avg_cases  total_deaths  new_deaths  \
# 1 2021-12-22      1501697       430     3437.0         26076           4
# 2 2021-12-21      1501267      4748     3810.0         26072           7
# 3 2021-12-20      1496519      6174     3466.0         26065           5
# 4 2021-12-19      1490345      2766     2944.0         26060           6
# 5 2021-12-18      1487579      3266     2703.0         26054           9
#
#    avg_deaths
# 1         7.0
# 2         8.0
# 3         8.0
# 4         9.0
# 5         9.0

# %%
df.tail()
# Out:
#       date_use  total_cases  new_case  avg_cases  total_deaths  new_deaths  \
# 658 2020-03-05          396        34        NaN             0           0
# 659 2020-03-04          362        19        NaN             0           0
# 660 2020-03-03          343        13        NaN             0           0
# 661 2020-03-02          330        19        NaN             0           0
# 662 2020-03-01          311        25        NaN             0           0
#
#      avg_deaths
# 658         NaN
# 659         NaN
# 660         NaN
# 661         NaN
# 662         NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 662 entries, 1 to 662
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date_use      662 non-null    datetime64[ns]
#  1   total_cases   662 non-null    int64
#  2   new_case      662 non-null    int64
#  3   avg_cases     656 non-null    float64
#  4   total_deaths  662 non-null    int64
#  5   new_deaths    662 non-null    int64
#  6   avg_deaths    656 non-null    float64
# dtypes: datetime64[ns](1), float64(2), int64(4)
# memory usage: 41.4 KB

# %%
fig, axs = plt.subplots(nrows=3, ncols=1, figsize=(10, 10))

axs[0].plot_date(df['date_use'], df['total_cases'], '-b', label='Total cases')
axs[0].set_ylabel('Total cases', color='b')
axs[0].tick_params(axis='y', labelcolor='b')
axs[0].set_title('Data for Los Angeles County')
ax_right = axs[0].twinx()
ax_right.plot_date(df['date_use'], df['total_deaths'], '-r', label='Total deaths')
ax_right.set_ylabel('Total deaths', color='r')
ax_right.tick_params(axis='y', labelcolor='r')


axs[1].plot_date(df['date_use'], df['new_case'], '-', label='New cases')
axs[1].plot_date(df['date_use'], df['avg_cases'], '-', label='Average cases')
axs[1].set_ylabel('Number of cases')
axs[1].legend()

axs[2].plot_date(df['date_use'], df['new_deaths'], '-', label='New deaths')
axs[2].plot_date(df['date_use'], df['avg_deaths'], '-', label='Average deaths')
axs[2].legend()
axs[2].set_xlabel('Date')
axs[2].set_ylabel('Number of deaths')
# Out:
# Text(0, 0.5, 'Number of deaths')

# %% [markdown]
# ### Same as above but gridded by point, not date

# %%
fig, axs = plt.subplots(nrows=3, ncols=1, figsize=(10, 10))

axs[0].plot( df['total_cases'], '-b', label='Total cases')
axs[0].set_ylabel('Total cases', color='b')
axs[0].tick_params(axis='y', labelcolor='b')
axs[0].set_title('Data for Los Angeles County')
ax_right = axs[0].twinx()
ax_right.plot( df['total_deaths'], '-r', label='Total deaths')
ax_right.set_ylabel('Total deaths', color='r')
ax_right.tick_params(axis='y', labelcolor='r')


axs[1].plot(df['new_case'], '-', label='New cases')
axs[1].plot(df['avg_cases'], '-', label='Average cases')
axs[1].legend()

axs[2].plot(df['new_deaths'], '-', label='New deaths')
axs[2].plot(df['avg_deaths'], '-', label='Average deaths')
axs[2].legend()

# %%
axs
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fe507469f60>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fe5074bd048>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7fe5074e8160>],
#       dtype=object)
